# %%
import numpy as np
import pandas as pd

# %%
column_names = ['user_Id', 'item_Id', 'rating', 'time_stamp']
df = pd.read_csv('u.data', sep="\t", names=column_names)

# %%
df.head()
# Out:
#    user_Id  item_Id  rating  time_stamp
# 0      196      242       3   881250949
# 1      186      302       3   891717742
# 2       22      377       1   878887116
# 3      244       51       2   880606923
# 4      166      346       1   886397596

# %%
ratings_df = pd.read_csv('ratings.csv')

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movie_df = pd.read_csv('movies.csv')

# %%
movie_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_df = movie_df.rename(columns={'movieId': 'item_Id'}, index=str)

# %%
movie_df.head()
# Out:
#    item_Id                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
new_df = pd.merge(df, movie_df, on ='item_Id')

# %%
new_df.head()
# Out:
#    user_Id  item_Id  rating  time_stamp                          title  \
# 0      196      242       3   881250949  Farinelli: il castrato (1994)
# 1       63      242       3   875747190  Farinelli: il castrato (1994)
# 2      226      242       5   883888671  Farinelli: il castrato (1994)
# 3      154      242       3   879138235  Farinelli: il castrato (1994)
# 4      306      242       5   876503793  Farinelli: il castrato (1994)
#
#           genres
# 0  Drama|Musical
# 1  Drama|Musical
# 2  Drama|Musical
# 3  Drama|Musical
# 4  Drama|Musical
